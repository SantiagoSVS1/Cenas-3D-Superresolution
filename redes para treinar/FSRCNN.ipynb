# %% [markdown]
# <a href="https://colab.research.google.com/github/Nhat-Thanh/FSRCNN-TF/blob/main/FSRCNN-TF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mount drive**

# %%
from google.colab import drive
from pathlib import Path

content_path = Path('/').absolute() / 'content'
drive_path = content_path / 'drive'
drive.mount(str(drive_path))
project_path = drive_path / 'MyDrive' / 'Colab Notebooks' / 'super_resolution_2'
# %cd "{project_path}"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/super_resolution_2

# %%
# !ls
# Out:
# FSRCNN.ipynb  FSRCNN-TF

# %% [markdown]
# # **Train**

# %%
# !git clone https://github.com/Nhat-Thanh/FSRCNN-TF.git
# Out:
# Cloning into 'FSRCNN-TF'...
# remote: Enumerating objects: 365, done.
# remote: Counting objects: 100% (113/113), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 365 (delta 43), reused 112 (delta 42), pack-reused 252
# Receiving objects: 100% (365/365), 50.75 MiB | 18.97 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# Updating files: 100% (260/260), done.

# %%
# %cd FSRCNN-TF/
# Out:
# /content/drive/MyDrive/Colab Notebooks/super_resolution_2/FSRCNN-TF

# %%
# !git pull
# Out:
# Already up to date.

# %%
# Train model x2
# !rm -rf dataset/*.npy
# !python train.py  --steps=200             \
                  --scale=2                  \
                  --batch_size=128           \
                  --save-best-only=0         \
                  --save-every=1000          \
                  --save-log=0               \
                  --ckpt-dir="checkpoint/x2"
# Out:
# dataset/train/im_001.png
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/super_resolution_2/FSRCNN-TF/train.py", line 51, in <module>
#     train_set.generate(lr_crop_size, hr_crop_size)
#   File "/content/drive/MyDrive/Colab Notebooks/super_resolution_2/FSRCNN-TF/utils/dataset.py", line 39, in generate
#     subim_data = resize_bicubic(subim_data, lr_crop_size, lr_crop_size)
#   File "/content/drive/MyDrive/Colab Notebooks/super_resolution_2/FSRCNN-TF/utils/common.py", line 73, in resize_bicubic
#     image = tf.clip_by_value(image, 0, 255)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py", line 1260, in op_dispatch_handler
#     return dispatch_target(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/clip_ops.py", line 114, in clip_by_value
#     t_max = math_ops.maximum(t_min, clip_value_min, name=name)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_math_ops.py", line 6341, in maximum
#     _result = pywrap_tfe.TFE_Py_FastPathExecute(
# KeyboardInterrupt
# ^C

# %%
# Train model x3
# !rm -rf dataset/*.npy
# !python train.py  --steps=200             \
                  --scale=3                  \
                  --batch_size=128           \
                  --save-best-only=0         \
                  --save-every=1000          \
                  --save-log=0               \
                  --ckpt-dir="checkpoint/x3"
# Out:
# dataset/train/im_001.png
# dataset/train/im_002.png
# dataset/train/im_003.png
# dataset/train/im_004.png
# dataset/train/im_005.png
# dataset/train/im_006.png
# dataset/train/im_007.png
# dataset/train/im_008.png
# dataset/train/im_009.png
# dataset/train/im_010.png
# dataset/train/im_011.png
# dataset/train/im_012.png
# dataset/train/im_013.png
# dataset/train/im_014.png
# dataset/train/im_015.png
# dataset/train/im_016.png
# dataset/train/im_017.png
# dataset/train/im_018.png
# dataset/train/im_019.png
# dataset/train/im_020.png
# dataset/train/im_021.png
# dataset/train/im_022.png
# dataset/train/im_023.png
# dataset/train/im_024.png
# dataset/train/im_025.png
# dataset/train/im_026.png
# dataset/train/im_027.png
# dataset/train/im_028.png
# dataset/train/im_029.png
# dataset/train/im_030.png
# dataset/train/im_031.png
# dataset/train/im_032.png
# dataset/train/im_033.png
# dataset/train/im_034.png
# dataset/train/im_035.png
# dataset/train/im_036.png
# dataset/train/im_037.png
# dataset/train/im_038.png
# dataset/train/im_039.png
# dataset/train/im_040.png
# dataset/train/im_041.png
# dataset/train/im_042.png
# dataset/train/im_043.png
# dataset/train/im_044.png
# dataset/train/im_045.png
# dataset/train/im_046.png
# dataset/train/im_047.png
# dataset/train/im_048.png
# dataset/train/im_049.png
# dataset/train/im_050.png
# dataset/train/im_051.png
# dataset/train/im_052.png
# dataset/train/im_053.png
# dataset/train/im_054.png
# dataset/train/im_055.png
# dataset/train/im_056.png
# dataset/train/im_057.png
# dataset/train/im_058.png
# dataset/train/im_059.png
# dataset/train/im_060.png
# dataset/train/im_061.png
# dataset/train/im_062.png
# dataset/train/im_063.png
# dataset/train/im_064.png
# dataset/train/im_065.png
# dataset/train/im_066.png
# dataset/train/im_067.png
# dataset/train/im_068.png
# dataset/train/im_069.png
# dataset/train/im_070.png
# dataset/train/im_071.png
# dataset/train/im_072.png
# dataset/train/im_073.png
# dataset/train/im_074.png
# dataset/train/im_075.png
# dataset/train/im_076.png
# dataset/train/im_077.png
# dataset/train/im_078.png
# dataset/train/im_079.png
# dataset/train/im_080.png
# dataset/train/im_081.png
# dataset/train/im_082.png
# dataset/train/im_083.png
# dataset/train/im_084.png
# dataset/train/im_085.png
# dataset/train/im_086.png
# dataset/train/im_087.png
# dataset/train/im_088.png
# dataset/train/im_089.png
# dataset/train/im_090.png
# dataset/train/im_091.png
# dataset/train/im_092.png
# dataset/train/im_093.png
# dataset/train/im_094.png
# dataset/train/im_095.png
# dataset/train/im_096.png
# dataset/train/im_097.png
# dataset/train/im_098.png
# dataset/train/im_099.png
# dataset/train/im_100.png
# dataset/train/t1.bmp
# dataset/train/t10.bmp
# dataset/train/t11.bmp
# dataset/train/t12.bmp
# dataset/train/t13.bmp
# dataset/train/t14.bmp
# dataset/train/t15.bmp
# dataset/train/t16.bmp
# dataset/train/t17.bmp
# dataset/train/t18.bmp
# dataset/train/t19.bmp
# dataset/train/t2.bmp
# dataset/train/t20.bmp
# dataset/train/t21.bmp
# dataset/train/t22.bmp
# dataset/train/t23.bmp
# dataset/train/t24.bmp
# dataset/train/t25.bmp
# dataset/train/t26.bmp
# dataset/train/t27.bmp
# dataset/train/t28.bmp
# dataset/train/t29.bmp
# dataset/train/t3.bmp
# dataset/train/t30.bmp
# dataset/train/t31.bmp
# dataset/train/t32.bmp
# dataset/train/t33.bmp
# dataset/train/t34.bmp
# dataset/train/t35.bmp
# dataset/train/t36.bmp
# dataset/train/t37.bmp
# dataset/train/t38.bmp
# dataset/train/t39.bmp
# dataset/train/t4.bmp
# dataset/train/t40.bmp
# dataset/train/t42.bmp
# dataset/train/t43.bmp
# dataset/train/t44.bmp
# dataset/train/t45.bmp
# dataset/train/t46.bmp
# dataset/train/t47.bmp
# dataset/train/t48.bmp
# dataset/train/t49.bmp
# dataset/train/t5.bmp
# dataset/train/t50.bmp
# dataset/train/t51.bmp
# dataset/train/t52.bmp
# dataset/train/t53.bmp
# dataset/train/t54.bmp
# dataset/train/t55.bmp
# dataset/train/t56.bmp
# dataset/train/t57.bmp
# dataset/train/t58.bmp
# dataset/train/t59.bmp
# dataset/train/t6.bmp
# dataset/train/t60.bmp
# dataset/train/t61.bmp
# dataset/train/t62.bmp
# dataset/train/t63.bmp
# dataset/train/t64.bmp
# dataset/train/t65.bmp
# dataset/train/t66.bmp
# dataset/train/t7.bmp
# dataset/train/t8.bmp
# dataset/train/t9.bmp
# dataset/train/tt1.bmp
# dataset/train/tt10.bmp
# dataset/train/tt12.bmp
# dataset/train/tt13.bmp
# dataset/train/tt14.bmp
# dataset/train/tt15.bmp
# dataset/train/tt16.bmp
# dataset/train/tt17.bmp
# dataset/train/tt18.bmp
# dataset/train/tt19.bmp
# dataset/train/tt2.bmp
# dataset/train/tt20.bmp
# dataset/train/tt21.bmp
# dataset/train/tt22.bmp
# dataset/train/tt23.bmp
# dataset/train/tt24.bmp
# dataset/train/tt25.bmp
# dataset/train/tt26.bmp
# dataset/train/tt27.bmp
# dataset/train/tt3.bmp
# dataset/train/tt4.bmp
# dataset/train/tt5.bmp
# dataset/train/tt6.bmp
# dataset/train/tt7.bmp
# dataset/train/tt8.bmp
# dataset/train/tt9.bmp
# dataset/validation/img_001_SRF_4_HR.png
# dataset/validation/img_002_SRF_4_HR.png
# dataset/validation/img_003_SRF_4_HR.png
# dataset/validation/img_004_SRF_4_HR.png
# dataset/validation/img_005_SRF_4_HR.png
# dataset/validation/img_006_SRF_4_HR.png
# dataset/validation/img_007_SRF_4_HR.png
# dataset/validation/img_008_SRF_4_HR.png
# dataset/validation/img_009_SRF_4_HR.png
# dataset/validation/img_010_SRF_4_HR.png
# dataset/validation/img_011_SRF_4_HR.png
# dataset/validation/img_012_SRF_4_HR.png
# dataset/validation/img_013_SRF_4_HR.png
# dataset/validation/img_014_SRF_4_HR.png
# FSRCNN model is created
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  conv2d (Conv2D)             (None, None, None, 56)    4256
#
#  p_re_lu (PReLU)             (None, None, None, 56)    56
#
#  conv2d_1 (Conv2D)           (None, None, None, 12)    684
#
#  p_re_lu_1 (PReLU)           (None, None, None, 12)    12
#
#  conv2d_2 (Conv2D)           (None, None, None, 12)    1308
#
#  conv2d_3 (Conv2D)           (None, None, None, 12)    1308
#
#  conv2d_4 (Conv2D)           (None, None, None, 12)    1308
#
#  conv2d_5 (Conv2D)           (None, None, None, 12)    1308
#
#  p_re_lu_2 (PReLU)           (None, None, None, 12)    12
#
#  conv2d_6 (Conv2D)           (None, None, None, 56)    728
#
#  p_re_lu_3 (PReLU)           (None, None, None, 56)    56
#
#  conv2d_transpose (Conv2DTr  (None, None, None, 3)     13611
#  anspose)
#
#  tf.clip_by_value (TFOpLamb  (None, None, None, 3)     0
#  da)
#
# =================================================================
# Total params: 24647 (96.28 KB)
# Trainable params: 24647 (96.28 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/super_resolution_2/FSRCNN-TF/train.py", line 77, in <module>
#     main()
#   File "/content/drive/MyDrive/Colab Notebooks/super_resolution_2/FSRCNN-TF/train.py", line 69, in main
#     model.summary()
# AttributeError: 'FSRCNN' object has no attribute 'summary'

# %%
# Train model x4
# !rm -rf dataset/*.npy
# !python train.py  --steps=200000             \
                  --scale=4                  \
                  --batch_size=128           \
                  --save-best-only=0         \
                  --save-every=1000          \
                  --save-log=0               \
                  --ckpt-dir="checkpoint/x4"

# %% [markdown]
# #**Test**

# %%
# Test on Set5
#!python test.py --scale=2 --ckpt-path="default"
# !python test.py --scale=3 --ckpt-path="default"
#!python test.py --scale=4 --ckpt-path="default"
# Out:
# 34.5881965637207

# %% [markdown]
# #**Demo**

# %%
# !python demo.py --image-path="dataset/test1.png"  \
                --ckpt-path="default"             \
                --scale=2

# %% [markdown]
# # **Dataset files**

# %%
# %%writefile dataset-files.sh
#
# OPTION=$1
# DATASET_DIR="/content/FSRCNN-TF/dataset"
# DRIVE_DIR="/content/drive/MyDrive/FSRCNN-TF"
# SUBSETS=("train" "validation")
# TYPE=("data" "labels")
#
# mkdir -p ${DRIVE_DIR}
# for type in ${TYPE[*]}; do
#     for subset in ${SUBSETS[*]}; do
#         # copy all generated dataset files to your drive
#         if [ "$OPTION" == "copy to drive" ]; then
#             cp -vf ${DATASET_DIR}/${type}_${subset}.npy ${DRIVE_DIR}
#
#         # copy all saved dataset files from your drive to dataset directory
#         elif [ "$OPTION" == "copy from drive" ]; then
#             cp -vf ${DRIVE_DIR}/${type}_${subset}.npy   ${DATASET_DIR}
#
#         # delete all generated dataset files in dataset directory
#         elif [ "${OPTION}" == "remove" ]; then
#             rm -vf ${DATASET_DIR}/${type}_${subset}.npy
#         fi
#     done
# done

# %%
# !bash dataset-files.sh "copy to drive"
# !bash dataset-files.sh "copy from drive"
# !bash dataset-files.sh "remove"

# %% [markdown]
# # **Checkpoint**

# %%
# %%writefile ckpt.sh
# OPTION=$1
#
# DRIVE_DIR="/content/drive/MyDrive/FSRCNN-TF"
# SRC="/content/FSRCNN-TF/checkpoint"
# DES="${DRIVE_DIR}/checkpoint"
# SUBSETS=("x2" "x3" "x4")
#
# mkdir -p ${DRIVE_DIR}
# for subset in ${SUBSETS[*]}; do
#     # remove all checkpoint files in sub-directories in checkpoint directory
#     if [ "${OPTION}" == "remove" ]; then
#         rm -vrf ${SRC}/${subset}
#         mkdir -p ${SRC}/${subset}
#
#     # copy all checkpoint directories to your drive
#     elif [ "${OPTION}" == "copy to drive" ]; then
#         mkdir -p ${DES}
#         mkdir -p ${DES}/${subset}
#         cp -vrf ${SRC}/${subset}/. ${DES}/${subset}
#
#     # copy all saved checkpoint files from your drive to checkpoint directory
#     elif [ "${OPTION}" == "copy from drive" ]; then
#         mkdir -p ${SRC}
#         mkdir -p ${SRC}/${subset}
#         cp -vrf ${DES}/${subset}/. ${SRC}/${subset}
#     fi
#
# done

# %%
# !bash ckpt.sh "copy from drive"
# !bash ckpt.sh "copy to drive"
# !bash ckpt.sh "remove"
